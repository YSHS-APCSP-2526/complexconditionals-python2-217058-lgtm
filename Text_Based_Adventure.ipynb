# %% [markdown]
# <a href="https://colab.research.google.com/github/YSHS-APCSP-2526/complexconditionals-python2-217058-lgtm/blob/main/Text_Based_Adventure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Requirements for text based adventure
# 1. You must have at least 2 different "paths" that are at least 4 decisions in length
# 2. Include an element of randomness (from the random library)
# 3. Include a list that is core to the text based adventure
# 4. Include a function that is called within your program that includes a while loop, and a parameter that influences a conditional statement in your function.
# 5. Commented Code.
# 6. A [digital flowchart](https://docs.google.com/document/d/1p2k3wL6gzjYWBuWxwEQptmbbOZZNsQrthlC12SNtYgY/edit?usp=sharing) that follows accepted symbols for representing code. You can use google slides or [draw.io](https://www.drawio.com/) for the flowchart.

# %%
def bruh3(response4):
  while response4 != "yes" and response4 !="no":
    response4 = input ("dude")
    if response4 == "no":
      return "You're an idiot."
    elif response4 == "yes":
      return "We are friends then."
def bruh2(response3):
  while response3 != "yes" and response3 !="no":
    response3 = input ("Ahem")
  if response3 == "no":
    return "Screw you!"
  elif response3 == "yes":
    bruh3(input("Do you know what 1 + 1 equals?"))
def bruh(response2):
  while response2 != "yes" and response2 !="no":
    response2 = input ("answer my question, are you stupid or not?")
  if response2 == "no":
    bruh2(input('So, do you like hotdogs?'))
  elif response2 == "yes":
    return "We cannot be friends."
def RV(response):
  while response != "yes" and response !="no":
    response = input("Invalid Response: Type yes or no, unless you are stupid.")
  if response == "yes":
    bruh(input("Are you stupid?"))
def choice1():
  response1 = input("Do you agree, yes or no?")
  response1 = RV()

RV(input("Hi, do you want to be friends?"))
